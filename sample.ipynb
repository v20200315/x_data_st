# %%
import pandas as pd
import requests
from datetime import datetime, timedelta

# %%
url = "http://127.0.0.1:8000/api/stock/date_range/?from=2024-11-01&to=2024-11-04"

# %%
response = requests.get(url)

# %%
stock_data = response.json()
df = pd.DataFrame(stock_data)

# %%
df
# Out:
#      trading_date stock_code  opening_price  closing_price  highest_price  \
# 0      2024-11-01     831726          10.97          14.65          14.65
# 1      2024-11-01     871634          18.44          24.75          24.75
# 2      2024-11-01     836961          25.20          32.21          32.21
# 3      2024-11-01     836807          10.35          13.18          13.18
# 4      2024-11-01     873305          25.48          31.92          31.92
# ...           ...        ...            ...            ...            ...
# 5343   2024-11-01     430139          35.98          29.55          36.99
# 5344   2024-11-01     837212          18.69          16.70          20.00
# 5345   2024-11-01     834415          22.08          18.02          22.15
# 5346   2024-11-01     833346          28.17          23.16          29.20
# 5347   2024-11-01     920066          42.00          40.68          46.68
#
#       lowest_price  trading_volume  trading_amount  price_range  \
# ...
